# %% [markdown]
# # 导入单元测试模块

# %%
import unittest
import raw2rgb_link.config

# %% [markdown]
# # 单元测试源码

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
__author__ = 'Zheng Jiacheng'
__version__ = '0.0.2'

import os
import numpy as np
from PIL import Image

from raw2rgb_link.config import *


class FileOperations(object):
    '''This module encapsulates part of the file operations of the raw2rgb module.

    '''
    def __init__(self):
        pass

    @staticmethod
    def get_file_list_from_path(path:'list or str', ext:str=""):
        L = list()
        if isinstance(path, list):
            for item in path:
                L.extend(FileOperations.get_file_list_from_path(item, ext))
        elif isinstance(path, str):
            if os.path.isdir(path):
                L.extend(FileOperations.get_file_list_from_str(path, ext))
            elif os.path.isfile(path) and isinstance(ext, str):
                L.append(path)  if not ext else (L.append(path) if os.path.splitext(path)[1] == ext else None)
        return L

    @staticmethod
    def get_file_list_from_str(path:str, ext:str=""):
        L = list()
        for root, _, files in os.walk(path):
            for file in files:
                if not ext:
                    L.append(os.path.join(root, file))
                elif ext == os.path.splitext(file)[1]:
                    L.append(os.path.join(root, file))
        return L
    
    @staticmethod
    def read_raw_data(path):
        "Open raw or mipi-raw format file."
        try:
            return np.fromfile(path, dtype=np.uint8).astype(np.uint16)
        except Exception as e:
            print_e("File read failed Exception:")
    
    @staticmethod
    def save(path:str, extension:str, rgb_array:np.ndarray):
        try:
            fullfilename, ext = os.path.splitext(path)
            fullfilename = fullfilename + extension
            Image.fromarray(rgb_array).save(fullfilename)
        except Exception as e:
            print("E: File written failed Exception:", e)
        else:
            print("M: File written successfully, path:", fullfilename)

# %% [markdown]
# # 单元测试

# %%
class TestFileOperations(unittest.TestCase):
    def test_get_file_list_from_path(self, path:list):
        tmp = FileOperations.get_file_list_from_path(path)
        print(tmp)
        self.assertTrue(type(tmp) is list)

# %%
tfo = TestFileOperations()

# %% [markdown]
# ## 测试get_file_list_from_path方法

# %%
tfo.test_get_file_list_from_path("/home/jc/Project/CViewer/GitLab/CViewer")
# Out:
# ['/home/jc/Project/CViewer/GitLab/CViewer/README.md', '/home/jc/Project/CViewer/GitLab/CViewer/.gitignore', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/mipiraw2raw.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/raw2rgb.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/const_def.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/fileoperations.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__init__.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/config.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/conversion_rules.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/mipiraw2raw.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/fileoperations.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/const_def.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/config.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/conversion_rules.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/config.cpython-38.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/__init__.cpython-38.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/file_operations_unit_test.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/mipiraw2raw_unit_test.py.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/.ipynb_checkpoints/file_operations_unit_test-checkpoint.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample_MIPIRAW10bit_Pattern_RGGB_W4000_H3000.raw', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample_MIPIRAW10bit_Pattern_RGGB_W4000_H3000.jpg', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample.jpg', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample.raw', '/home/jc/Project/CViewer/GitLab/CViewer/.git/FETCH_HEAD', '/home/jc/Project/CViewer/GitLab/CViewer/.git/config', '/home/jc/Project/CViewer/GitLab/CViewer/.git/packed-refs', '/home/jc/Project/CViewer/GitLab/CViewer/.git/description', '/home/jc/Project/CViewer/GitLab/CViewer/.git/HEAD', '/home/jc/Project/CViewer/GitLab/CViewer/.git/COMMIT_EDITMSG', '/home/jc/Project/CViewer/GitLab/CViewer/.git/index', '/home/jc/Project/CViewer/GitLab/CViewer/.git/info/exclude', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-rebase.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-push.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-receive.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-commit.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/commit-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/post-update.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/update.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/applypatch-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/fsmonitor-watchman.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/prepare-commit-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-applypatch.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/04/ea4d4f42fa0929212ec22fd425338cf390116f', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/04/ec981b1f1fe7e9a730f8cb419e3a6731adbf4c', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/1cfff8fa23b8870167bc2c20a5049a93bb20a0', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/d5d28905f877258490dc295889a6aaca740324', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/8c0ae14ccf1837b9d2ef7ebb694869619679d4', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/be40639e791ad50cc9a85a18653c92111799e8', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/efba064c9195f4b48c809cb160de4f0487a289', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/3b7cb7947495773cc8694bbb16cad3b62d8d52', '/hom ...

# %%
tfo.test_get_file_list_from_path(["/home/jc/Project/CViewer/GitLab/CViewer",1])
# Out:
# ['/home/jc/Project/CViewer/GitLab/CViewer/README.md', '/home/jc/Project/CViewer/GitLab/CViewer/.gitignore', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/mipiraw2raw.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/raw2rgb.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/const_def.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/fileoperations.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__init__.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/config.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/conversion_rules.py', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/mipiraw2raw.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/fileoperations.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/const_def.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/config.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/conversion_rules.cpython-36.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/config.cpython-38.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/raw2rgb/__pycache__/__init__.cpython-38.pyc', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/file_operations_unit_test.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/mipiraw2raw_unit_test.py.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/python/unit_test/raw2rgb/.ipynb_checkpoints/file_operations_unit_test-checkpoint.ipynb', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample_MIPIRAW10bit_Pattern_RGGB_W4000_H3000.raw', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample_MIPIRAW10bit_Pattern_RGGB_W4000_H3000.jpg', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample.jpg', '/home/jc/Project/CViewer/GitLab/CViewer/sample/Sample.raw', '/home/jc/Project/CViewer/GitLab/CViewer/.git/FETCH_HEAD', '/home/jc/Project/CViewer/GitLab/CViewer/.git/config', '/home/jc/Project/CViewer/GitLab/CViewer/.git/packed-refs', '/home/jc/Project/CViewer/GitLab/CViewer/.git/description', '/home/jc/Project/CViewer/GitLab/CViewer/.git/HEAD', '/home/jc/Project/CViewer/GitLab/CViewer/.git/COMMIT_EDITMSG', '/home/jc/Project/CViewer/GitLab/CViewer/.git/index', '/home/jc/Project/CViewer/GitLab/CViewer/.git/info/exclude', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-rebase.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-push.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-receive.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-commit.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/commit-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/post-update.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/update.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/applypatch-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/fsmonitor-watchman.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/prepare-commit-msg.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/hooks/pre-applypatch.sample', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/04/ea4d4f42fa0929212ec22fd425338cf390116f', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/04/ec981b1f1fe7e9a730f8cb419e3a6731adbf4c', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/1cfff8fa23b8870167bc2c20a5049a93bb20a0', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/d5d28905f877258490dc295889a6aaca740324', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/76/8c0ae14ccf1837b9d2ef7ebb694869619679d4', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/be40639e791ad50cc9a85a18653c92111799e8', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/efba064c9195f4b48c809cb160de4f0487a289', '/home/jc/Project/CViewer/GitLab/CViewer/.git/objects/20/3b7cb7947495773cc8694bbb16cad3b62d8d52', '/hom ...
