# %%
file = open("/home/jc/Project/CViewer/GitLab/CViewer/sample/IMG_20200817_205527-037_req[1]_b[0]_IFE[1][8]_w[6016]_h[4512]_s[0]_RealtimePreviewSAT1.RAWMIPI","rb")

# %%
data = file.read()

# %%
len(data)
# Out:
# 33930240

# %%
6016*4512*10/8
# Out:
# 33930240.0

# %%
file = open("/home/jc/Project/CViewer/GitLab/CViewer/sample/IMG_20200817_205527-111_req[1]_b[0]_IFE[1][9]_w[752]_h[4464]_s[0]_RealtimePreviewSAT1.RAWPLAIN16","rb")

# %%
data = file.read()

# %%
len(data)
# Out:
# 6713856

# %%
752*4464*16/8
# Out:
# 6713856.0

# %%
list(data)
# Out:
# [64,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  62,
#  0,
#  66,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  66,
#  0,
#  62,
#  0,
#  66,
#  0,
#  66,
#  0,
#  64,
#  0,
#  66,
#  0,
#  62,
#  0,
#  64,
#  0,
#  66,
#  0,
#  62,
#  0,
#  66,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  64,
#  0,
#  66,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  62,
#  0,
#  66,
#  0,
#  64,
#  0,
#  60,
#  0,
#  66,
#  0,
#  64,
#  0,
#  62,
#  0,
#  62,
#  0,
#  62,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
#  0,
#  64,
# ...

# %%
import numpy as np

# %%
npfile = np.fromfile("/home/jc/Project/CViewer/GitLab/CViewer/sample/IMG_20200817_205527-111_req[1]_b[0]_IFE[1][9]_w[752]_h[4464]_s[0]_RealtimePreviewSAT1.RAWPLAIN16",dtype=np.uint16)

# %%
npfile
# Out:
# array([64, 64, 66, ..., 66, 66, 62], dtype=uint16)

# %%
npfile.shape
# Out:
# (3356928,)
